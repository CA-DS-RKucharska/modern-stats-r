# %%
git_token = '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'
username = 'rosaok'
repository = 'modern-stats-r'

# !git config --global user.email "rosakucharska@outlookm"
# !git config --global user.name "Your Name"

# mount gdrive
from google.colab import drive
drive.mount('/gdrive')

# %cd '/gdrive/MyDrive/GitHub/modern-stats-r'
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/MyDrive/GitHub/modern-stats-r

# %%
# !git remote set-url origin https://{username}:{git_token}@github.com/{username}/{repository}.git
# !git add .
# !git status
# !git commit -m 'Update chapter 2 notebook'
# !git push origin dev
# Out:
# On branch dev
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   git.ipynb
# 	new file:   modern-stats-r.gitignore
# 	modified:   notebooks/2 - the basics.ipynb
#
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@11de91ed1b4d.(none)')
# Everything up-to-date
